# %% [markdown]
# <a href="https://colab.research.google.com/github/SamaSamrin/Python-Data-Visualization-Guide/blob/main/DV_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Basics

# %% [markdown]
# Reading CSV file from mounted Google Drive with Pandas

# %%
drinks = pd.read_csv("/content/drive/MyDrive/Data Science/data/Starbucks Menu Nutrition/starbucks_drinkMenu_expanded.csv")

display(drinks)
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
cereals = pd.read_csv('/content/drive/MyDrive/Data Science/data/cereals.csv')

display(cereals)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ## Exploring the Starbucks Drinks dataset

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage                   242 non-null    object
#  2   Beverage_prep              242 non-null    object
#  3   Calories                   242 non-null    int64
#  4    Total Fat (g)             242 non-null    object
#  5   Trans Fat (g)              242 non-null    float64
#  6   Saturated Fat (g)          242 non-null    float64
#  7    Sodium (mg)               242 non-null    int64
#  8    Total Carbohydrates (g)   242 non-null    int64
#  9   Cholesterol (mg)           242 non-null    int64
#  10   Dietary Fibre (g)         242 non-null    int64
#  11   Sugars (g)                242 non-null    int64
#  12   Protein (g)               242 non-null    float64
# ...

# %%
drinks.describe()
# Out:
#          Calories  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# count  242.000000      242.000000         242.000000    242.000000
# mean   193.871901        1.307025           0.037603      6.363636
# std    102.863303        1.640259           0.071377      8.630257
# min      0.000000        0.000000           0.000000      0.000000
# 25%    120.000000        0.100000           0.000000      0.000000
# 50%    185.000000        0.500000           0.000000      5.000000
# 75%    260.000000        2.000000           0.100000     10.000000
# max    510.000000        9.000000           0.300000     40.000000
#
#         Total Carbohydrates (g)   Cholesterol (mg)   Dietary Fibre (g)  \
# count                 242.000000        242.000000          242.000000
# mean                  128.884298         35.991736            0.805785
# std                    82.303223         20.795186            1.445944
# min                     0.000000          0.000000            0.000000
# ...

# %%
#total number of unique beverages
print("Total Number of Unique Beverages:", len(drinks['Beverage'].value_counts()), "\n")

#unique beverages
display(drinks['Beverage'].value_counts())
# Out:
# Total Number of Unique Beverages: 33
# Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)        12
# White Chocolate Mocha (Without Whipped Cream)          12
# Tazo® Full-Leaf Tea Latte                              12
# Tazo® Green Tea Latte                                  12
# Tazo® Chai Tea Latte                                   12
# Coffee                                                 12
# Hot Chocolate (Without Whipped Cream)                  12
# Caramel Macchiato                                      12
# Cappuccino                                             12
# Vanilla Latte (Or Other Flavoured Latte)               12
# Caffè Mocha (Without Whipped Cream)                    12
# Caffè Latte                                            12
# Iced Brewed Coffee (With Milk & Classic Syrup)          9
# Caramel (Without Whipped Cream)                         9
# Java Chip (Without Whipped Cream)                       9
# Mocha (Without Whipped Cream)                           9
# ...

# %%
#total number of unique beverage categories
print("Total Number of Beverage Categories:", len(drinks['Beverage_category'].value_counts()), "\n")

#names of the beverage categories
display(drinks['Beverage_category'].value_counts())
# Out:
# Total Number of Beverage Categories: 9
# Classic Espresso Drinks              58
# Tazo® Tea Drinks                     52
# Signature Espresso Drinks            40
# Frappuccino® Blended Coffee          36
# Shaken Iced Beverages                18
# Frappuccino® Blended Crème           13
# Frappuccino® Light Blended Coffee    12
# Smoothies                             9
# Coffee                                4
# Name: Beverage_category, dtype: int64

# %%
#total number of unique beverage varieties
print("Total Number of Beverage Varieties:", len(drinks['Beverage_prep'].value_counts()), "\n")

#names of the beverage varieties
display(drinks['Beverage_prep'].value_counts())
# Out:
# Total Number of Beverage Varieties: 13
# Soymilk               66
# 2% Milk               50
# Grande Nonfat Milk    26
# Tall Nonfat Milk      23
# Venti Nonfat Milk     22
# Whole Milk            16
# Short Nonfat Milk     12
# Tall                   7
# Grande                 7
# Venti                  7
# Short                  4
# Solo                   1
# Doppio                 1
# Name: Beverage_prep, dtype: int64

# %% [markdown]
# ## Exploring the Cereals Dataset

# %%
cereals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
cereals.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# # Pie Chart

# %% [markdown]
# - color palettes (seaborn)
# - legend
# - font color and size

# %% [markdown]
# **With Seaborn Palette and Matplotlib**

# %%
plt.figure(figsize=(8,8))
random_numbers = [35, 21, 29, 39, 11]
random_labels = ['slice 1', 'slice 2', 'slice 3', 'slice 4', 'slice 5']

plt.pie(random_numbers, labels=random_labels, colors=sns.color_palette('muted'), autopct='%1.2f%%',  textprops = {'fontsize':16})

plt.legend()
plt.show()

#plt.pie(data, labels=labels, colors = colors,
#         autopct = '%0.0f%%',
#         explode = explode,
#         shadow = 'True',
#         startangle = 90,
#         textprops = {'color': 'Green','fontsize':16},
#         wedgeprops = {'linewidth': 6},
#         frame = 'true' ,
#         center = (0.1,0.1),
#         rotatelabels = 'true')
# #

# %% [markdown]
# ## Cereals Dataset

# %%
cereals['type'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'), textprops={'fontsize':14})
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Starbucks Drinks Dataset

# %%
plt.figure(figsize=(10,10))
plt.title("Proportions of Beverage Types in Starbucks", fontsize=16)
drinks['Beverage_category'].value_counts().plot(kind='pie', autopct='%1.2f%%', textprops={'color':'white', 'fontsize':16})

plt.legend() #sorted according to percentages by default
plt.ylabel('')
plt.show()

# %% [markdown]
# [Pie charts are not directly available in Seaborn](https://www.dataforeverybody.com/matplotlib-seaborn-pie-charts/)

# %% [markdown]
# ## Donut Chart

# %% [markdown]
# ---

# %% [markdown]
# # Bar Plot

# %% [markdown]
# - colors
# - markers
# - annotations

# %% [markdown]
# ## with Seaborn

# %%
plt.figure(figsize=(15,8))
plt.title('Sugar Quantity in Each Starbucks Beverage Category', fontsize=16)
chart = sns.barplot(x='Beverage_category', y=' Sugars (g)', data=drinks)

plt.xticks(rotation=90, fontsize=12)
plt.yticks(np.arange(0,65,5))

plt.grid()
plt.show()

#The Black Line:
#They are error bars. They can display either confidence intervals or the standard deviation.  
# The bar plot shows an aggregation of some values. The error bar shows how spread out the original non-aggregated data was (simplified!). 
# That is also the reason why no bar shows up when there was only one value. 
# I wil point you towards the seaborn documentation. Pay extra attention to the "estimator" and "ci" parameters to start with

# %% [markdown]
# ## Horizontal Bar Plot with Matplotlib and values shown

# %%
plt.figure(figsize=(15,7))
plt.title('Horizontal Bar Plot of Starbucks Drinks Varieties', fontsize=14)
#sns.set_style("whitegrid")
drinks['Beverage_prep'].value_counts().plot(kind='barh', color="blueviolet")

plt.xlabel('Count of Each Variety', fontsize=14, color='purple')
plt.ylabel('Drink Varieties', fontsize=14, color='purple')

#for displaying values above/alongside each bar
for index, value in enumerate(drinks['Beverage_prep'].value_counts()):
    plt.text(value, index, str(value), fontsize=12)

plt.grid()
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(20,8))
sns.histplot(x="Calories", data=drinks, binwidth=25, color='magenta')

plt.xticks(np.arange(0,526,25))
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.histplot(x='Calories', data=drinks, binwidth=25, fill=False, kde=True, color="magenta")
plt.xticks(np.arange(0,526,25))

plt.show()

# %% [markdown]
# ## kernel density estimates (KDEs)

# %%
plt.figure(figsize=(20,8))
sns.displot(x="Calories", data=drinks, color='magenta', kind="kde")

#plt.xticks(np.arange(0,601,100))
plt.show()

# %% [markdown]
# ## ECDF (empirical cumulative distribution function)

# %%
plt.figure(figsize=(12,8))
sns.histplot(x="Calories", data=drinks, cumulative=True, binwidth=25)

plt.yticks(np.arange(0,251,50))
plt.xticks(np.arange(0,526,25))
plt.grid()
plt.show()

# %% [markdown]
# # Line Plot

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(20,10))
plt.title("Higher Sugar leads to Higher Calories in Different Starbucks Drinks", fontsize=16)

sns.scatterplot(x='Calories', y=' Sugars (g)', data=drinks, hue='Beverage_category', s=70)

plt.yticks(np.arange(0, 86, 5))
plt.xticks(np.arange(0, 600, 50))
plt.grid()
plt.show()

# %% [markdown]
# ## Observations
#
# *   Classic Espresso Drinks have the lowest sugar quantity
# *   Frappuccino Coffees have the highest sugar quantity

# %% [markdown]
# # Regression Plot

# %%
plt.figure(figsize=(20,10))
plt.title("Higher Sugar leads to Higher Calories in Starbucks Drinks", fontsize=16)

sns.regplot(x='Calories', y=' Sugars (g)', data=drinks, line_kws={'color':'red'})

plt.yticks(np.arange(0, 86, 5))
plt.xticks(np.arange(0, 600, 50))
plt.grid()
plt.show()

# %% [markdown]
# #  Box Plot

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="Calories", data=drinks, color='lawngreen')
plt.xticks(np.arange(0,551,50), fontsize=14)

plt.show()

# %% [markdown]
# # Violin Plot

# %%
plt.figure(figsize=(22,5))

plt.subplot(1,2,1)
sns.violinplot(x='Calories', data=drinks, color='yellow')
plt.xticks(np.arange(0,601,50))
plt.grid()

plt.subplot(1,2,2)
sns.violinplot(x='Calories', data=drinks, color='lawngreen', showfliers=False)
plt.xticks(np.arange(0,601,50))
plt.grid()

plt.show()

# %%
plt.figure(figsize=(25,10))
sns.violinplot(y='calories', data=cereals, x='mfr', palette=sns.color_palette('bright'))
plt.yticks(np.arange(0,201,25))
plt.xlabel('MFR', fontsize=12)
plt.ylabel('Calories', fontsize=12)
plt.grid()
